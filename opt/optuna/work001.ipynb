# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#%pip install tensorflow==2.10.1
#%pip install keras
#%pip install matplotlib==3.4.0
# %pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.6 MB/s eta 0:00:00
# ...

# %%
import os
from os import path

#dir_base = os.getcwd() + '/drive/MyDrive/kumagai/Colab Notebooks/optuna/work001'
dir_base = os.getcwd() + '/drive/MyDrive/Colab Notebooks/optuna/work001'

print(dir_base)
os.chdir(dir_base)
# Out:
# /content/drive/MyDrive/Colab Notebooks/optuna/work001

# %%
# %run work001_0.py
# Out:
# x0 0
# x1 2
# dict_items([('i', 1), ('x0', 0), ('x1', 2)])

# %%
# %run work001_1.py
# Out:
# [I 2023-04-18 21:10:52,613] A new study created in memory with name: no-name-74879d1b-5d49-4c7b-be23-208d95179c1a
# [I 2023-04-18 21:10:52,620] Trial 0 finished with value: 1.320304975910128 and parameters: {'x1': 1.7332740857007958, 'x2': 0.5262896991948278, 'z1': 1, 'z2': 1}. Best is trial 0 with value: 1.320304975910128.
# [I 2023-04-18 21:10:52,628] Trial 1 finished with value: 2.473722297592184 and parameters: {'x1': 0.4778486693810291, 'x2': 1.290949200991083, 'z1': 2, 'z2': 2}. Best is trial 0 with value: 1.320304975910128.
# [I 2023-04-18 21:10:52,635] Trial 2 finished with value: 0.6260192272148632 and parameters: {'x1': 0.6685987429767053, 'x2': 0.23885692317666307, 'z1': 1, 'z2': 1}. Best is trial 2 with value: 0.6260192272148632.
# [I 2023-04-18 21:10:52,644] Trial 3 finished with value: 1.6756845705418126 and parameters: {'x1': 1.2042266229252339, 'x2': 0.5025699183251395, 'z1': 1, 'z2': 2}. Best is trial 2 with value: 0.6260192272148632.
# ...
